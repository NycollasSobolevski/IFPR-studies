# %%
#Aula 1
# !pip install networkx
# !pip install pandas
# !pip install matplotlib

# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd

graph_type = nx.Graph()
df = pd.read_csv('test2.csv')
G = nx.from_pandas_edgelist(df, create_using=graph_type)

nx.draw(G, with_labels=True)
plt.show()
print(nx.dijkstra_path(G, 4, 6))

# %%
import networkx as nx
import numpy as np
A = np.array([
    [1, 1],
    [2, 1]
    ])
G = nx.from_numpy_array(A)
G.edges(data=True)

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

input_data = pd.read_csv('rom2.csv', index_col=0)
#G = nx.DiGraph(input_data.values) #Direcionado
#G = nx.MultiDiGraph(input_data.values) #Direcionado
G = nx.Graph(input_data.values) #Não direcionado

#For plotting this graph use
nx.draw(G, with_labels=True)
plt.show()

print(nx.dijkstra_path(G, 2 , 4, weight='weight'))#hospital
print(nx.dijkstra_path(G, 2 , 5, weight='weight'))#padaria
print(nx.dijkstra_path(G, "Rua A - Rua B" , "Rua C - Rua Z", weight='weight'))#padaria

# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd

graph_type = nx.Graph()
df = pd.read_csv('test3.csv')
G = nx.from_pandas_edgelist(df, create_using=graph_type)

nx.draw(G, with_labels=True)
plt.show()

# %%
import networkx as nx

import matplotlib.pyplot as plt

g = nx.Graph()

# Adding one node
g.add_node("1", label="Person", name="Kevin Bacon", age=64)

# Adding multiple nodes
g.add_nodes_from(
    [
        ("2", {"label": "Person", "name": "Ian McKellen", "age": 83}),
        ("3", {"label": "Person", "name": "James McAvoy", "age": 43}),
        ("4", {"label": "Person", "name": "Michael Fassbender", "age": 45}),
    ]
)

# Adding one edge
g.add_edge("1", "3", type="ACTED_WITH")

# Adding multiple edges
g.add_edges_from([("1", "4"), ("2", "3"), ("2", "4")], type="ACTED_WITH")

# Graph drawing
pos = nx.circular_layout(g)
nx.draw(g, pos, node_size=10000)

labels = nx.get_node_attributes(g, "name")
edge_labels = nx.get_edge_attributes(g, "type")

nx.draw_networkx_labels(g, pos, labels=labels, font_size=10, font_color="white")
nx.draw_networkx_edge_labels(g, pos, edge_labels=edge_labels, font_size=10)

plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()

G.add_edge('a', 'b', weight=2)
G.add_edge('b', 'c', weight=4)
G.add_edge('a', 'c', weight=10)
G.add_edge('c', 'd', weight=6)
G.add_edge('b', 'd', weight=2)
G.add_edge('b', 'e', weight=5)
G.add_edge('e', 'f', weight=8)
G.add_edge('d', 'f', weight=8)

path = nx.shortest_path(G)
st = 'a' #start node
end = 'e' #end node
nx.draw(G,  with_labels=True, node_color='skyblue')
labels = nx.get_edge_attributes(G,'weight')
plt.show()

print(nx.dijkstra_path(G, "a", "e", weight='weight'))

# %%
import networkx as nx
import matplotlib.pyplot as plt

Nodes = [('A', 'B'),('A', 'C'), ('C', 'D'), ('D', 'B'), ('C', 'B'), ('D', 'E'), ('E', 'F'), ('D', 'F')]

G = nx.Graph() #Não direcionado


num = 1 #name edge
for node in Nodes:
    G.add_edge(*node, num = num, weight = 1)
    num += int(num*1.5)

pos = nx.spring_layout(G) #Visualização
edge_labels = nx.get_edge_attributes(G, 'num')
nx.draw(G,  with_labels=True, node_color='skyblue', pos=pos)
nx.draw_networkx_edge_labels(G, pos, edge_labels = edge_labels, font_color='red')
plt.show()

path = nx.shortest_path(G) #Caminhos mais curtos
st = 'A' #start node
end = 'E' #end node
path_edges = [edge_labels.get(x, edge_labels.get((x[1],x[0]))) for x in zip(path[st][end], path[st][end][1:])]
print('Path by nodes: ', path[st][end])
print('Path by edges: ', path_edges)

print( nx.all_shortest_paths(G,"A", "E"))

print("dijkstra_path:", nx.dijkstra_path(G, "A", "E", weight='num'))#O peso ficou na propriedade num


print(nx.single_source_dijkstra(G, "A", "E", weight='weight'))
print(nx.shortest_path(G,source="A",target="E", weight='weight'))
print(nx.bidirectional_dijkstra(G, "A", "E", weight='weight'))

print(nx.shortest_path_length(G, "A", "E", weight='weight'))

print(nx.shortest_path(G, "A", "E", weight='weight'))
print(nx.path_weight(G, "A", "E"))


print(nx.astar_path(G, "A", "E"))
print(nx.astar_path_length(G, "A", "E"))

# %%
import networkx as nx
import matplotlib.pyplot as plt
g = nx.Graph()
g.add_edge(131,673,weight=673)
g.add_edge(131,201,weight=201)
g.add_edge(673,96,weight=96)
g.add_edge(201,96,weight=96)
nx.draw(g,with_labels=True)
plt.show()

# %%
G = nx.path_graph(5)
print(nx.shortest_path(G, source=0, target=4))
#[0, 1, 2, 3, 4]

# %%
p = nx.shortest_path(G, source=0)  # target not specified
p[3] # shortest path from source=0 to target=3
#[0, 1, 2, 3]

# %%
p = nx.shortest_path(G, target=4)  # source not specified
p[1] # shortest path from source=1 to target=4
#[1, 2, 3, 4]

# %%
p = nx.shortest_path(G)  # source, target not specified
p[2][4] # shortest path from source=2 to target=4
#[2, 3, 4]

# %%
import matplotlib.pyplot as plt #biblioteca para gerar a figura
import networkx as nx #biblioteca para gerar o grafo (estrutura)

G = nx.Graph() #Cria um grafo não direcional

#Adiciona as arestas
G.add_edge("a", "b", weight=0.6) #Source/Emissor:a, Target/Destinatário:b, peso:0.6
G.add_edge("a", "c", weight=0.2)
G.add_edge("c", "d", weight=0.1)
G.add_edge("c", "e", weight=0.7)
G.add_edge("c", "f", weight=0.9)
G.add_edge("a", "d", weight=0.3)

elarge = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] > 0.5]
esmall = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] <= 0.5]

pos = nx.spring_layout(G, seed=7)  # positions for all nodes - seed for reproducibility

# nodes
nx.draw_networkx_nodes(G, pos, node_size=700)

# edges
nx.draw_networkx_edges(G, pos, edgelist=elarge, width=6)
nx.draw_networkx_edges(
    G, pos, edgelist=esmall, width=6, alpha=0.5, edge_color="b", style="dashed"
)

# node labels
nx.draw_networkx_labels(G, pos, font_size=20, font_family="sans-serif")
# edge weight labels
edge_labels = nx.get_edge_attributes(G, "weight")
nx.draw_networkx_edge_labels(G, pos, edge_labels)

ax = plt.gca()
ax.margins(0.08)
plt.axis("off")
plt.tight_layout()
plt.show()

print(nx.shortest_path(G,source="e",target="b", weight='weight'))
# Out:
# ['e', 'c', 'a', 'b']

# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd


graph_type = nx.Graph()
df = pd.read_csv('./Atividade/sourceTarget.csv')
G = nx.from_pandas_edgelist(df, create_using=graph_type)

nx.draw(G, with_labels=True)
plt.show()
print(nx.dijkstra_path(G, 2, 50))
# Out:
# [2, 3, 4, 7, 11, 16, 21, 22, 23, 26, 27, 28, 32, 33, 37, 38, 39, 40, 41, 44, 45, 46, 47, 48, 49, 50]

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

input_data = pd.read_csv('./Atividade/atividade result.CSV', index_col=0, sep=';')
# G = nx.DiGraph(input_data.values) #Direcionado
#G = nx.MultiDiGraph(input_data.values) #Direcionado
G = nx.Graph(input_data.values) #Não direcionado

nx.draw(G, with_labels=True)

# #For plotting this graph use
# nx.draw(G, with_labels=True)
# plt.show()

print(nx.dijkstra_path(G, 1 , 50, weight='weight'))
# print(nx.dijkstra_path(G, 1 , 50, weight='weight'))
# Out:
# [1, 2, 3, 6, 10, 15, 20, 21, 22, 25, 26, 27, 31, 32, 36, 37, 38, 39, 40, 43, 44, 45, 46, 47, 48, 49, 50]

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# Carregar os dados do CSV
input_data = pd.read_csv('./Atividade/atividade result.CSV', index_col=0, sep=';')

# Criar o grafo
G = nx.Graph()

# Adicionar as arestas com pesos ao grafo, utilizando os índices do CSV diretamente
for i, row in input_data.iterrows():
    for j, weight in row.items():
        if weight != 0:  # Somente adicionar arestas com peso não zero
            G.add_edge(i, int(j), weight=weight)

# Desenhar o grafo com os nós numerados de 1 a 52
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_size=500, font_size=10)
plt.show()

# Calcular o caminho mais curto entre dois nós (neste exemplo, de 1 a 50)
shortest_path = nx.dijkstra_path(G, 1, 50, weight='weight')
print(shortest_path)
# Out:
# [1, 2, 3, 4, 7, 11, 16, 21, 22, 23, 26, 27, 28, 32, 33, 37, 38, 39, 40, 41, 44, 45, 46, 47, 48, 49, 50]

# %%
#! Atividade Com Centralidade de Grau (22-11-2024)

# Com a atividade do labirinto, identifique a centralidade de grau. Cada vértice vai ter um valor particular.
# Qual são os 5 vértices mais importantes e onde eles ficam no labirinto?
# Poste o print do gráfico, dos valores de centralidade e argumente a respeito.

import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# Carregar os dados do CSV
input_data = pd.read_csv('./Atividade/atividade result.CSV', index_col=0, sep=';')

# Criar o grafo
G = nx.Graph()

# Adicionar as arestas com pesos ao grafo, utilizando os índices do CSV diretamente
for i, row in input_data.iterrows():
    for j, weight in row.items():
        if weight != 0:  # Somente adicionar arestas com peso não zero
            G.add_edge(i, int(j), weight=weight)

#!---------------------------- Calculando a Centralidade de Grau ----------------------------
degreeCentrality = nx.degree_centrality(G)
degreeSorted = sorted(degreeCentrality, key=degreeCentrality.get, reverse=True) #ordenando por ordem decrescente
print(str(degreeSorted[:5])) # todo; mostrando o top 5 mais importante 
print(str(degreeCentrality))
#!----------------------------   ----------------------------   ----------------------------

# Desenhar o grafo (1 à 52)
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_size=500, font_size=10)
plt.show()
# Out:
# [4, 7, 11, 16, 13]
# ...

# %%
#! Atividade Com Centralidade de Grau (22-11-2024)

# Com a atividade do labirinto, identifique a centralidade de grau. Cada vértice vai ter um valor particular.
# Qual são os 5 vértices mais importantes e onde eles ficam no labirinto?
# Poste o print do gráfico, dos valores de centralidade e argumente a respeito.

import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# Carregar os dados do CSV
input_data = pd.read_csv('./Atividade/atividade result.CSV', index_col=0, sep=';')

# Criar o grafo
G = nx.Graph()

# Adicionar as arestas com pesos ao grafo, utilizando os índices do CSV diretamente
for i, row in input_data.iterrows():
    for j, weight in row.items():
        if weight != 0:  # Somente adicionar arestas com peso não zero
            G.add_edge(i, int(j), weight=weight)

#!---------------------------- Calculando a Centralidade de Grau ----------------------------
centrality = nx.eigenvector_centrality(G, max_iter=200)
sortedCentrality = sorted((v, f"{c:0.2f}") for v, c in centrality.items())

print(sortedCentrality)
#!----------------------------   ----------------------------   ----------------------------

# Desenhar o grafo (1 à 52)
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_size=500, font_size=10)
plt.show()
# Out:
# [(1, '0.11'), (2, '0.13'), (3, '0.20'), (4, '0.35'), (5, '0.20'), (6, '0.13'), (7, '0.42'), (8, '0.23'), (9, '0.12'), (10, '0.05'), (11, '0.42'), (12, '0.25'), (13, '0.16'), (14, '0.07'), (15, '0.07'), (16, '0.34'), (17, '0.18'), (18, '0.10'), (19, '0.05'), (20, '0.02'), (21, '0.19'), (22, '0.12'), (23, '0.10'), (24, '0.05'), (25, '0.02'), (26, '0.06'), (27, '0.04'), (28, '0.04'), (29, '0.02'), (30, '0.01'), (31, '0.01'), (32, '0.02'), (33, '0.02'), (34, '0.01'), (35, '0.00'), (36, '0.00'), (37, '0.01'), (38, '0.01'), (39, '0.00'), (40, '0.00'), (41, '0.00'), (42, '0.00'), (43, '0.00'), (44, '0.00'), (45, '0.00'), (46, '0.00'), (47, '0.00'), (48, '0.00'), (49, '0.00'), (50, '0.00'), (51, '0.00'), (52, '0.00')]
